# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import nltk

skin_disease_dataset =  [
"User : For the last couple of days, I've been troubled by persistent rashes causing irritation.\nExpert : Are you presently on any medications or engaged in any medical treatments?",
"User : Over the recent days, I've noticed some discomfort spreading across both my right and left limbs.\nExpert : Are there medications you're presently using or specific medical treatments you're undergoing?",
"User : Recently, discomfort has emerged on both my right and left limbs, causing unease.\nExpert : Have there been recent changes in your medication regimen or ongoing medical treatments?",
"User : The sensation of discomfort has become noticeable in both my right and left limb\nExpert : Are you currently on any prescribed medications or receiving medical treatments?",
"User : I've been feeling discomfort in the back of my body and in underarms\nExpert : Have there been any modifications to your medication routine or ongoing medical treatments lately?",
"User : . Over the past three days, I've been consistently taking doxycycline tablets.\nExpert : Is there any bleeding or fluid oozing from the skin lesion?",
"User : Over the past three days, doxycycline tablets have been included in my medication routine.\nExpert : Is there any bleeding or fluid oozing from the skin lesion?",
"User : I've been using azithromycin tablets as prescribed for the last three days.\nExpert : Is there any bleeding or fluid oozing from the skin lesion?",
"User : I've adhered to a three-day course of azithromycin tablets recently.\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : I've incorporated azithromycin tablets into my daily medication routine for the past three days.\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : Over the past three days, painkillers have been included in my medication routine\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : Painkillers have been part of my daily routine for the past three days.\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : Over the past three days, I've been consistently using painkillers.\nExpert : Have you noticed any bleeding or the presence of fluids oozing from the skin lesion?",
"User : I’ve been under anabolic steroids for past few weeks.\nExpert : Have you noticed any bleeding or the presence of fluids oozing from the skin lesion?",
"User : while there's no noticeble oozing, it does have a greasy sensation.\nExpert : Have you noticed any bleeding or the presence of fluids oozing from the skin lesion?",
"User : no evident oozing, but there is a greasy texture to it.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : I've got blisters, and ther's pus emerging from certain areas.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : Yes, there is bleeding and pus coming out of it.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : Certain areas are exhibiting blisters, with the release of pus.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : it doesn't seem to be oozing, but there's a subtle greasiness\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : No, there is no bleeding or fluid discharge but it feels dry and crusty\nExpert : Does the skin lesion show any tendency to bleed or release fluids?",
"User : some regions are displaying blisters, with visible pus being discharged.\nExpert : Does the skin lesion show any tendency to bleed or release fluids?",
"User : No there is no that sort of thing!\nExpert : Have you observed bleeding or the discharge of fluids from the skin lesion?",
"User : i'm not experiencing anything like that\nExpert : Is there any occurrence of bleeding or fluids oozing from the skin lesion?",
"User : There is no occurence of such symptoms for me.\nExpert : Does the skin lesion display any signs of bleeding or the release of fluids?",
"User : No, I'm not dealing with that kind of situation.\nExpert : Have you experienced bleeding or noticed fluids oozing from the skin lesion?",
"User : there is presence of blister but does not bleed or any sort of fluid coming out of it.\nExpert : Is there any evidence of bleeding or fluid discharge associated with the skin lesion?",
"User : yes, pus coming out of it.\nExpert : Is there any evidence of bleeding or fluid discharge associated with the skin lesion?",
"User : occurence of blisters accompanied by the discharge of pus from specific regions.\nExpert : Does your family have any past instances of skin cancer?",
"User : Yes there is clean fluid come out of it.\nExpert : Does your family have any past instances of skin cancer?",
"User : No there is no such sort of thing.\nExpert : Is there a family history of skin cancer that you're aware of?",
"User : I've noted the development of blisters, with evident pus in some regions.\nExpert : Have there been cases of skin cancer within your family?",
"User : I haven't identified any such symptoms in my current condition.\nExpert : Have there been cases of skin cancer within your family?",
"User : I'm not currently encountering anything resembling that.\nExpert : Have there been cases of skin cancer within your family?",
"User : No oozing or any fluid discharge but have some discomfort and irritation.\nExpert : Have there been cases of skin cancer within your family?",
"User : I have only rashes and redness in some regions.\nExpert : Have there been cases of skin cancer within your family?",
"User : No, only rashes and irritation.\nExpert : Does skin cancer run in your family's medical history?",
"User : As far as I know, there's no history of skin cancer in my family.\nExpert : Does skin cancer run in your family's medical history?",
"User : I think my grandfather was diagnosed with skin cancer.\nExpert : Are there any recorded incidents of skin cancer among your relatives?",
"User : As far as I'm aware, there haven't been any cases of skin cancer in my family.\nExpert : Is there a known family background of skin cancer?",
"User : If I remember correctly, my Mother had a history of skin cancer.\nExpert : Have any family members been diagnosed with skin cancer in the past?",
"User : If I remember correctly, my Father had a history of skin cancer.\nExpert : Have any family members been diagnosed with skin cancer in the past?",
"User : If I remember correctly, my Dad had a history of skin cancer.\nExpert : Is skin cancer part of your family's health history?",
"User : If I remember correctly, my mom had a history of skin cancer.\nExpert : Does your family have a track record of skin cancer cases?",
"User : I have no knowledge of any cases of skin cancer in my family history.\nExpert : Are there any instances of skin cancer in your family's medical background?",
"User : No, not that I'm aware of.\nExpert : Have you identified any specific patterns or triggers that exacerbate the skin lesion?",
"User : No, not that I'm aware of maybe there are some of my relatives have it.\nExpert : Have you identified any specific patterns or triggers that exacerbate the skin lesion?",
"User : No, there is no one that i know of my relative have it.\nExpert : Are there particular factors or patterns that seem to worsen the skin lesion for you?",
"User : From what I know, there's no family history of skin cancer\n.Expert : Are there particular factors or patterns that seem to worsen the skin lesion for you?",
"User : I think there was a time when my grandmother faced skin cancer.\nExpert : Have you observed any recurring patterns or triggers that intensify the skin lesion?",
"User : I think there was a time when my grandpa faced skin cancer.\nExpert : Have you observed any recurring patterns or triggers that intensify the skin lesion?",
"User : No there is no one like that.\nExpert : Have you observed any recurring patterns or triggers that intensify the skin lesion?",
"User : Yes I think so\nExpert : Are there any identifiable factors or patterns that contribute to the worsening of the skin lesion?",
"User : Yes I think its my cousin but I'm not sure of it.\nExpert : Are there any identifiable factors or patterns that contribute to the worsening of the skin lesion?",
"User : The skin lesion worsened after days of non-stop work without breaks.\nExpert : Have you noticed any consistent patterns or triggers that make the skin lesion worse?",
"User : i think it maybe due to work stress\nExpert : Have you noticed any consistent patterns or triggers that make the skin lesion worse?",
"User : The condition worsened following the application of a specific cream.\nExpert : Are there specific factors or patterns that you've recognized as exacerbating the skin lesion?",
"User : No there is nothing like that.\nExpert : Have you observed any recurring triggers or patterns that negatively impact the skin lesion?",
"User : After using detergent, the situation seemed to deteriorate.\nExpert : Have you observed any recurring triggers or patterns that negatively impact the skin lesion?"
]

# Tokenize the dataset
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
formatted_dataset = [tokenizer.encode(entry, return_tensors='pt') for entry in skin_disease_dataset]

# Load the pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Set the model to training mode
model.train()

# Fine-tune parameters
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)

# Fine-tune for a few epochs
for epoch in range(3):  # adjust the number of epochs
    for entry in formatted_dataset:
        optimizer.zero_grad()
        outputs = model(entry, labels=entry)
        loss = outputs.loss
        loss.backward()
        optimizer.step()

# Save the fine-tuned model and tokenizer
model.save_pretrained('fine_tuned_skin_diagnosis_model')
tokenizer.save_pretrained('fine_tuned_skin_diagnosis_model')  

# Load the fine-tuned model
context_model = GPT2LMHeadModel.from_pretrained('fine_tuned_skin_diagnosis_model')
context_tokenizer = GPT2Tokenizer.from_pretrained('fine_tuned_skin_diagnosis_model')

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

dataset = [
"User : For the last couple of days, I've been troubled by persistent rashes causing irritation.\nExpert : Are you presently on any medications or engaged in any medical treatments?",
"User : Over the recent days, I've noticed some discomfort spreading across both my right and left limbs.\nExpert : Are there medications you're presently using or specific medical treatments you're undergoing?",
"User : Recently, discomfort has emerged on both my right and left limbs, causing unease.\nExpert : Have there been recent changes in your medication regimen or ongoing medical treatments?",
"User : The sensation of discomfort has become noticeable in both my right and left limb\nExpert : Are you currently on any prescribed medications or receiving medical treatments?",
"User : I've been feeling discomfort in the back of my body and in underarms\nExpert : Have there been any modifications to your medication routine or ongoing medical treatments lately?",
"User : . Over the past three days, I've been consistently taking doxycycline tablets.\nExpert : Is there any bleeding or fluid oozing from the skin lesion?",
"User : Over the past three days, doxycycline tablets have been included in my medication routine.\nExpert : Is there any bleeding or fluid oozing from the skin lesion?",
"User : I've been using azithromycin tablets as prescribed for the last three days.\nExpert : Is there any bleeding or fluid oozing from the skin lesion?",
"User : I've adhered to a three-day course of azithromycin tablets recently.\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : I've incorporated azithromycin tablets into my daily medication routine for the past three days.\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : Over the past three days, painkillers have been included in my medication routine\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : Painkillers have been part of my daily routine for the past three days.\nExpert : Does the skin lesion exhibit any signs of bleeding or fluid discharge?",
"User : Over the past three days, I've been consistently using painkillers.\nExpert : Have you noticed any bleeding or the presence of fluids oozing from the skin lesion?",
"User : I’ve been under anabolic steroids for past few weeks.\nExpert : Have you noticed any bleeding or the presence of fluids oozing from the skin lesion?",
"User : while there's no noticeble oozing, it does have a greasy sensation.\nExpert : Have you noticed any bleeding or the presence of fluids oozing from the skin lesion?",
"User : no evident oozing, but there is a greasy texture to it.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : I've got blisters, and ther's pus emerging from certain areas.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : Yes, there is bleeding and pus coming out of it.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : Certain areas are exhibiting blisters, with the release of pus.\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : it doesn't seem to be oozing, but there's a subtle greasiness\nExpert : Is there any indication of bleeding or fluid discharge from the skin lesion?",
"User : No, there is no bleeding or fluid discharge but it feels dry and crusty\nExpert : Does the skin lesion show any tendency to bleed or release fluids?",
"User : some regions are displaying blisters, with visible pus being discharged.\nExpert : Does the skin lesion show any tendency to bleed or release fluids?",
"User : No there is no that sort of thing!\nExpert : Have you observed bleeding or the discharge of fluids from the skin lesion?",
"User : i'm not experiencing anything like that\nExpert : Is there any occurrence of bleeding or fluids oozing from the skin lesion?",
"User : There is no occurence of such symptoms for me.\nExpert : Does the skin lesion display any signs of bleeding or the release of fluids?",
"User : No, I'm not dealing with that kind of situation.\nExpert : Have you experienced bleeding or noticed fluids oozing from the skin lesion?",
"User : there is presence of blister but does not bleed or any sort of fluid coming out of it.\nExpert : Is there any evidence of bleeding or fluid discharge associated with the skin lesion?",
"User : yes, pus coming out of it.\nExpert : Is there any evidence of bleeding or fluid discharge associated with the skin lesion?",
"User : occurence of blisters accompanied by the discharge of pus from specific regions.\nExpert : Does your family have any past instances of skin cancer?",
"User : Yes there is clean fluid come out of it.\nExpert : Does your family have any past instances of skin cancer?",
"User : No there is no such sort of thing.\nExpert : Is there a family history of skin cancer that you're aware of?",
"User : I've noted the development of blisters, with evident pus in some regions.\nExpert : Have there been cases of skin cancer within your family?",
"User : I haven't identified any such symptoms in my current condition.\nExpert : Have there been cases of skin cancer within your family?",
"User : I'm not currently encountering anything resembling that.\nExpert : Have there been cases of skin cancer within your family?",
"User : No oozing or any fluid discharge but have some discomfort and irritation.\nExpert : Have there been cases of skin cancer within your family?",
"User : I have only rashes and redness in some regions.\nExpert : Have there been cases of skin cancer within your family?",
"User : No, only rashes and irritation.\nExpert : Does skin cancer run in your family's medical history?",
"User : As far as I know, there's no history of skin cancer in my family.\nExpert : Does skin cancer run in your family's medical history?",
"User : I think my grandfather was diagnosed with skin cancer.\nExpert : Are there any recorded incidents of skin cancer among your relatives?",
"User : As far as I'm aware, there haven't been any cases of skin cancer in my family.\nExpert : Is there a known family background of skin cancer?",
"User : If I remember correctly, my Mother had a history of skin cancer.\nExpert : Have any family members been diagnosed with skin cancer in the past?",
"User : If I remember correctly, my Father had a history of skin cancer.\nExpert : Have any family members been diagnosed with skin cancer in the past?",
"User : If I remember correctly, my Dad had a history of skin cancer.\nExpert : Is skin cancer part of your family's health history?",
"User : If I remember correctly, my mom had a history of skin cancer.\nExpert : Does your family have a track record of skin cancer cases?",
"User : I have no knowledge of any cases of skin cancer in my family history.\nExpert : Are there any instances of skin cancer in your family's medical background?",
"User : No, not that I'm aware of.\nExpert : Have you identified any specific patterns or triggers that exacerbate the skin lesion?",
"User : No, not that I'm aware of maybe there are some of my relatives have it.\nExpert : Have you identified any specific patterns or triggers that exacerbate the skin lesion?",
"User : No, there is no one that i know of my relative have it.\nExpert : Are there particular factors or patterns that seem to worsen the skin lesion for you?",
"User : From what I know, there's no family history of skin cancer\n.Expert : Are there particular factors or patterns that seem to worsen the skin lesion for you?",
"User : I think there was a time when my grandmother faced skin cancer.\nExpert : Have you observed any recurring patterns or triggers that intensify the skin lesion?",
"User : I think there was a time when my grandpa faced skin cancer.\nExpert : Have you observed any recurring patterns or triggers that intensify the skin lesion?",
"User : No there is no one like that.\nExpert : Have you observed any recurring patterns or triggers that intensify the skin lesion?",
"User : Yes I think so\nExpert : Are there any identifiable factors or patterns that contribute to the worsening of the skin lesion?",
"User : Yes I think its my cousin but I'm not sure of it.\nExpert : Are there any identifiable factors or patterns that contribute to the worsening of the skin lesion?",
"User : The skin lesion worsened after days of non-stop work without breaks.\nExpert : Have you noticed any consistent patterns or triggers that make the skin lesion worse?",
"User : i think it maybe due to work stress\nExpert : Have you noticed any consistent patterns or triggers that make the skin lesion worse?",
"User : The condition worsened following the application of a specific cream.\nExpert : Are there specific factors or patterns that you've recognized as exacerbating the skin lesion?",
"User : No there is nothing like that.\nExpert : Have you observed any recurring triggers or patterns that negatively impact the skin lesion?",
"User : After using detergent, the situation seemed to deteriorate.\nExpert : Have you observed any recurring triggers or patterns that negatively impact the skin lesion?"
]

# Load the fine-tuned model
context_model = GPT2LMHeadModel.from_pretrained('fine_tuned_skin_diagnosis_model')
context_tokenizer = GPT2Tokenizer.from_pretrained('fine_tuned_skin_diagnosis_model')

# Function to tokenize and filter nouns
def tokenize_and_filter_nouns(user_input):
    tokens = nltk.word_tokenize(user_input)
    nouns = [word for word, pos in nltk.pos_tag(tokens) if pos.startswith('NN')]
    return nouns

# Initialize a list to store symptoms
symptoms_list = []

# Vectorize the dataset using TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(dataset)
print("Expert: Hello! What is your problem? Can you describe it briefly?")
for i in range(2):
    # User input
    user_input = input("User: ")
    noun_list = tokenize_and_filter_nouns(user_input)
    tokenized_user_input = context_tokenizer.encode(user_input, return_tensors='pt')

    # Generate a response using the fine-tuned model
    output = context_model.generate(
        tokenized_user_input,
        max_length=200,
        num_beams=5,
        no_repeat_ngram_size=2,
        eos_token_id=context_tokenizer.eos_token_id
    )

    # Decode the fine-tuned model response
    fine_tuned_response = context_tokenizer.decode(output[0], skip_special_tokens=True)

    # Use user_input directly as extracted_symptoms
    extracted_symptoms = noun_list

    # Store the extracted symptoms in the list
    symptoms_list.extend(extracted_symptoms)

    # Calculate cosine similarity between user input and dataset entries
    user_input_vector = vectorizer.transform([user_input])
    similarities = cosine_similarity(user_input_vector, X)

    # Find the index of the entry with the highest similarity
    best_match_index = similarities.argmax()

    # Display the enhanced response
    print("Expert:", dataset[best_match_index].split("\nExpert : ")[1]) 
    list=fine_tuned_response.split("?") 
    print("Fine-tuned Model Response:", list[-(i+1)] + "?" if i < len(list) else list[0] + "?")
    print("Stored Symptoms:", symptoms_list)
# Out:
# Expert: Hello! What is your problem? Can you describe it briefly?
# User:  I have experienced with itchy skin and inflammation for a past few days
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Expert: Have you noticed any bleeding or the presence of fluids oozing from the skin lesion?
# Fine-tuned Model Response:  Is there evidence of?
# Stored Symptoms: ['skin', 'inflammation', 'days']
# User:  till now I didn't noticed any bleeding in my affected parts
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
import spacy

data = {
    'Symptoms': ["itchy rash, redness", "scaly patches, inflammation", "raised bumps, itching", "blistering, oozing, pain",
                 "red spots, fever, fatigue", "dark, irregular moles", "dry, itchy skin, thickened plaques",
                 "pink or red rash, circular shape", "small, fluid-filled blisters", "swollen, painful joints, skin rash"],
    'SkinDisease': ["Dermatitis", "Psoriasis", "Hives", "Herpes", "Measles", "Melanoma", "Eczema", "Ringworm", "Chickenpox", "Lupus"]
}

df = pd.DataFrame(data)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['Symptoms'], df['SkinDisease'], test_size=0.2, random_state=42)

# Build a pipeline with a TF-IDF vectorizer and a Naive Bayes classifier
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

# Train the model
model.fit(X_train, y_train)
symptoms_ls=[i.lower() for i in symptoms_list]
# Extracting nouns and adjectives from user input for prediction
user_symptoms = " ".join(symptoms_ls)

# Make a prediction
predicted_disease = model.predict([user_symptoms])

# Display the predicted disease
print("Predicted Skin Disease:", predicted_disease[0])
# Out:
# Predicted Skin Disease: Lupus
